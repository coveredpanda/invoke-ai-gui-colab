# %% [markdown]
# # Для того, чтобы установить Invoke Ai, запустите код в каждой из форм.
# Для запуска сервера потребуется аккаунт на [ngrok](https://dashboard.ngrok.com/login)
#
# # To use Invoke Ai, launch the code in every form below.
# You will need an account on [ngrok](https://dashboard.ngrok.com/login)
#
# **[Repo](https://github.com/peaashmeter/invoke-ai-gui-colab)**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Во время этого этапа Colab крашится, это нормально
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:09
# 🔁 Restarting kernel...

# %%
#@title Подготовка репозитория Invoke Ai { display-mode: "form" }
# %cd /home

# !git clone -n https://github.com/invoke-ai/InvokeAI.git
# %cd InvokeAI
# !git checkout 69b15024a93ecfbbb555c956f745e9748c12f044

#dnspython fix
# !echo '    - dnspython==2.2.1' >> environments-and-requirements/environment-lin-cuda.yml

#huggingface fix
# !echo '    - huggingface-hub==0.26.5' >> environments-and-requirements/environment-lin-cuda.yml

#Werkzeug fix
# !echo '    - Werkzeug==2.2.2' >> environments-and-requirements/environment-lin-cuda.yml

#opencv fix
# !sed -i 's/opencv-python==4.5.5.64/opencv-python==4.8.0.74/g' environments-and-requirements/environment-lin-cuda.yml

# !ln -sf environments-and-requirements/environment-lin-cuda.yml environment.yml
# !ls -la

# %cd ..

# !git clone https://github.com/peaashmeter/invoke-ai-gui-colab.git


# %cd invoke-ai-gui-colab

# %cp cross_attention_control.py ../InvokeAI/ldm/models/diffusion/cross_attention_control.py
# %cp globals.py ../InvokeAI/ldm/invoke/globals.py
# %cd /home/invoke-ai-gui-colab
# Out:
# /home
# Cloning into 'InvokeAI'...
# remote: Enumerating objects: 216586, done.
# remote: Counting objects: 100% (32309/32309), done.
# remote: Compressing objects: 100% (1427/1427), done.
# remote: Total 216586 (delta 31492), reused 30995 (delta 30836), pack-reused 184277 (from 1)
# Receiving objects: 100% (216586/216586), 318.48 MiB | 29.26 MiB/s, done.
# Resolving deltas: 100% (171865/171865), done.
# /home/InvokeAI
# Note: switching to '69b15024a93ecfbbb555c956f745e9748c12f044'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 69b15024a update python requirements (#2251)
# total 212
# drwxr-xr-x 19 root root  4096 Dec  9 00:30 .
# drwxr-xr-x  1 root root  4096 Dec  9 00:30 ..
# drwxr-xr-x  4 root root  4096 Dec  9 00:30 assets
# drwxr-xr-x  3 root root  4096 Dec  9 00:30 backend
# drwxr-xr-x  2 root root  4096 Dec  9 00:30 binary_installer
# -rw-r--r--  1 root root  5247 Dec  9 00:30 CODE_OF_CONDUCT.md
# drwxr-xr-x  3 root root  4096 Dec  9 00:30 configs
# drwxr-xr-x  3 root root  4096 Dec  9 00:30 .dev_scripts
# drwxr-xr-x  2 root root  4096 Dec  9 00:30 docker-build
# -rw-r--r--  1 root root   312 Dec  9 00:30 .dockerignore
# drwxr-xr-x  8 root root  4096 Dec  9 00:30 docs
# -rw-r--r--  1 root root   179 Dec  9 00:30 .editorconfig
# drwxr-xr-x  2 root root  4096 Dec  9 00:30 environments-and-requirements
# lrwxrwxrwx  1 root root    54 Dec  9 00:30 environment.yml -> environments-and-requirements/environment-lin-cuda.yml
# drwxr-xr-x  6 root root  4096 Dec  9 00:30 frontend
# drwxr-xr-x  8 root root  4096 Dec  9 00:30 .git
# -rw-r--r--  1 root root   262 Dec  9 00:30 .gitattributes
# drwxr-xr-x  4 root root  4096 Dec  9 00:30 .github
# -rw-r--r--  1 root root  4443 Dec  9 00:30 .gitignore
# -rw-r--r--  1 root root     0 Dec  9 00:30 .gitmodules
# drwxr-xr-x  3 root root  4096 Dec  9 00:30 installer
# -rw-r--r--  1 root root  5049 Dec  9 00:30 InvokeAI_Statement_of_Values.md
# drwxr-xr-x  6 root root  4096 Dec  9 00:30 ldm
# -rw-r--r--  1 root root  1070 Dec  9 00:30 LICENSE
# -rw-r--r--  1 root root 14555 Dec  9 00:30 LICENSE-ModelWeights.txt
# -rw-r--r--  1 root root 32950 Dec  9 00:30 main.py
# -rw-r--r--  1 root root  2663 Dec  9 00:30 mkdocs.yml
# drwxr-xr-x  2 root root  4096 Dec  9 00:30 notebooks
# -rw-r--r--  1 root root   247 Dec  9 00:30 .prettierrc.yaml
# -rw-r--r--  1 root root 10122 Dec  9 00:30 README.md
# drwxr-xr-x  3 root root  4096 Dec  9 00:30 scripts
# -rw-r--r--  1 root root  3099 Dec  9 00:30 setup.py
# -rw-r--r--  1 root root  5152 Dec  9 00:30 shell.nix
# -rw-r--r--  1 root root  8587 Dec  9 00:30 Stable_Diffusion_v1_Model_Card.md
# drwxr-xr-x  4 root root  4096 Dec  9 00:30 static
# drwxr-xr-x  2 root root  4096 Dec  9 00:30 tests
# /home
# Cloning into 'invoke-ai-gui-colab'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 131 (delta 59), reused 47 (delta 35), pack-reused 52 (from 1)
# Receiving objects: 100% (131/131), 51.88 KiB | 830.00 KiB/s, done.
# Resolving deltas: 100% (75/75), done.
# /home/invoke-ai-gui-colab
# /home/invoke-ai-gui-colab

# %%
# !pip install -U huggingface-hub
# Out:
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.26.5-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from huggingface-hub)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/site-packages (from huggingface-hub) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/site-packages (from huggingface-hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/site-packages (from huggingface-hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/site-packages (from huggingface-hub) (4.66.1)
# Collecting typing-extensions>=3.7.4.3 (from huggingface-hub)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests->huggingface-hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests->huggingface-hub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests->huggingface-hub) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests->huggingface-hub) (2023.11.17)
# Downloading huggingface_hub-0.26.5-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.8/447.8 kB 13.9 MB/s eta 0:00:00
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.6/179.6 kB 15.5 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Installing collected packages: typing-extensions, fsspec, filelock, huggingface-hub
# Successfully installed filelock-3.16.1 fsspec-2024.10.0 huggingface-hub-0.26.5 typing-extensions-4.12.2

# %%
#@title Установка зависимостей, в норме занимает ~10 минут { display-mode: "form" }
# %cd ../InvokeAI
# !pip install pyngrok --quiet
# !conda env update
# !source activate invokeai ; python scripts/configure_invokeai.py --skip-sd-weights --yes

# %cp ../invoke-ai-gui-colab/models.yaml /root/invokeai/configs
# Out:
# /home/InvokeAI
# Channels:
#  - pytorch
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# Downloading and Extracting Packages:
# pytorch-1.12.1       | 76.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
# torchvision-0.13.1   | 6.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# torchaudio-0.12.1    | 6.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# pytorch-mutex-1.0    | 3 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
# torchaudio-0.12.1    | 6.0 MB    | :   0% 0.002597880754672943/1 [00:00<00:51, 51.52s/it]
#
#
# pytorch-1.12.1       | 76.7 MB   | :   0% 0.00020381492932663835/1 [00:00<13:00, 780.75s/it]
#
#
# pytorch-mutex-1.0    | 3 KB      | : 100% 1.0/1 [00:00<00:00,  6.67it/s]
# torchvision-0.13.1   | 6.1 MB    | :   0% 0.0025442637288371423/1 [00:00<01:27, 87.43s/it]
#
# pytorch-1.12.1       | 76.7 MB   | :   4% 0.038521021642734646/1 [00:00<00:05,  5.61s/it]
# pytorch-1.12.1       | 76.7 MB   | :  98% 0.9817765145664169/1 [00:01<00:00,  1.01s/it]
#
# torchaudio-0.12.1    | 6.0 MB    | : 100% 1.0/1 [00:02<00:00,  3.03s/it]
#
# torchaudio-0.12.1    | 6.0 MB    | : 100% 1.0/1 [00:02<00:00,  3.03s/it]
# torchvision-0.13.1   | 6.1 MB    | : 100% 1.0/1 [00:02<00:00,  2.99s/it]
#
#
#
#
#
#
#
# done
# done
# done
# | Ran pip subprocess with arguments:
# ['/usr/local/envs/invokeai/bin/python', '-m', 'pip', 'install', '-U', '-r', '/home/InvokeAI/condaenv.85wdb5tt.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Collecting clip
#   Cloning https://github.com/openai/CLIP.git (to revision main) to /tmp/pip-install-yhide5jz/clip_dde5a8b1d4be4e2fa4590c25daa99bcb
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting k-diffusion
#   Cloning https://github.com/Birch-san/k-diffusion.git (to revision mps) to /tmp/pip-install-yhide5jz/k-diffusion_14927fea363d423aa748400f549123f1
#   Resolved https://github.com/Birch-san/k-diffusion.git to commit b23db2229953b109e8559c9756545e42eaa0172e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting clipseg
#   Cloning https://github.com/invoke-ai/clipseg.git (to revision relaxed-python-requirement) to /tmp/pip-install-yhide5jz/clipseg_64df88e9fd644b0ab2837a18e479e145
#   Resolved https://github.com/invoke-ai/clipseg.git to commit 1f754751c85d7d4255fa681f4491ff5711c1c288
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gfpgan
#   Cloning https://github.com/invoke-ai/GFPGAN (to revision basicsr-1.4.2) to /tmp/pip-install-yhide5jz/gfpgan_5e9f86801e52479e9691907b175138f9
#   Resolved https://github.com/invoke-ai/GFPGAN to commit c796277a1cf77954e5fc0b288d7062d162894248
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pypatchmatch
#   Cloning https://github.com/invoke-ai/PyPatchMatch (to revision 0.1.5) to /tmp/pip-install-yhide5jz/pypatchmatch_93353b25336a4869aa15ece0fadd3d77
#   Resolved https://github.com/invoke-ai/PyPatchMatch to commit c1415412a308608038a5768a1f0ed926afc84915
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Obtaining file:///home/InvokeAI (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 32))
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: albumentations==0.4.3 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: diffusers==0.6.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: einops==0.3.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: eventlet in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 4)) (0.38.0)
# Requirement already satisfied: flask==2.1.3 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 5)) (2.1.3)
# Requirement already satisfied: flask_cors==3.0.10 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 6)) (3.0.10)
# Requirement already satisfied: flask_socketio==5.3.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 7)) (5.3.0)
# Requirement already satisfied: getpass_asterisk in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 8)) (1.0.1)
# Requirement already satisfied: imageio-ffmpeg==0.4.2 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 9)) (0.4.2)
# Requirement already satisfied: imageio==2.9.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 10)) (2.9.0)
# Requirement already satisfied: kornia==0.6.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: omegaconf==2.2.3 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 12)) (2.2.3)
# Requirement already satisfied: opencv-python==4.8.0.74 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 13)) (4.8.0.74)
# Requirement already satisfied: picklescan in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 14)) (0.0.18)
# Requirement already satisfied: pillow==9.2.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 15)) (9.2.0)
# Requirement already satisfied: pudb==2019.2 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 16)) (2019.2)
# Requirement already satisfied: pyreadline3 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 17)) (3.5.4)
# Requirement already satisfied: pytorch-lightning==1.7.7 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (1.7.7)
# Requirement already satisfied: realesrgan in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 19)) (0.3.0)
# Requirement already satisfied: send2trash==1.8.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 20)) (1.8.0)
# Requirement already satisfied: streamlit==1.12.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (1.12.0)
# Requirement already satisfied: taming-transformers-rom1504 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 22)) (0.0.6)
# Requirement already satisfied: test-tube>=0.7.5 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 23)) (0.7.5)
# Requirement already satisfied: torch-fidelity==0.3.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 24)) (0.3.0)
# Requirement already satisfied: torchmetrics==0.7.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 25)) (0.7.0)
# Requirement already satisfied: transformers==4.21.3 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 26)) (4.21.3)
# Requirement already satisfied: dnspython==2.2.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 33)) (2.2.1)
# Requirement already satisfied: huggingface-hub==0.11.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 34)) (0.11.1)
# Requirement already satisfied: Werkzeug==2.2.2 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from -r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 35)) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/envs/invokeai/lib/python3.9/site-packages (from albumentations==0.4.3->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 1)) (1.9.1)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from albumentations==0.4.3->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 1)) (1.23.3)
# Requirement already satisfied: imgaug<0.2.7,>=0.2.5 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from albumentations==0.4.3->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 1)) (0.2.6)
# Requirement already satisfied: PyYAML in /usr/local/envs/invokeai/lib/python3.9/site-packages (from albumentations==0.4.3->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from albumentations==0.4.3->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 1)) (4.10.0.84)
# Requirement already satisfied: importlib-metadata in /usr/local/envs/invokeai/lib/python3.9/site-packages (from diffusers==0.6.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 2)) (8.5.0)
# Requirement already satisfied: requests in /usr/local/envs/invokeai/lib/python3.9/site-packages (from diffusers==0.6.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: filelock in /usr/local/envs/invokeai/lib/python3.9/site-packages (from diffusers==0.6.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 2)) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from diffusers==0.6.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 2)) (2024.11.6)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from flask==2.1.3->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from flask==2.1.3->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from flask==2.1.3->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 5)) (3.1.4)
# Requirement already satisfied: Six in /usr/local/envs/invokeai/lib/python3.9/site-packages (from flask_cors==3.0.10->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: python-socketio>=5.0.2 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from flask_socketio==5.3.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 7)) (5.11.4)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from kornia==0.6.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 11)) (1.12.1)
# Requirement already satisfied: packaging in /usr/local/envs/invokeai/lib/python3.9/site-packages (from kornia==0.6.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 11)) (24.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/envs/invokeai/lib/python3.9/site-packages (from omegaconf==2.2.3->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 12)) (4.9.3)
# Requirement already satisfied: urwid>=1.1.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from pudb==2019.2->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 16)) (2.6.16)
# Requirement already satisfied: pygments>=1.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from pudb==2019.2->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 16)) (2.18.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (4.12.2)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (4.67.1)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (2024.10.0)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (0.3.2)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (2.18.0)
# Requirement already satisfied: pandas>=0.21.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (2.2.3)
# Requirement already satisfied: python-dateutil in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (2.9.0.post0)
# Requirement already satisfied: toml in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (0.10.2)
# Requirement already satisfied: validators>=0.2 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (0.34.0)
# Requirement already satisfied: watchdog in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (6.0.0)
# Requirement already satisfied: tornado>=5.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (6.4.2)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (5.5.0)
# Requirement already satisfied: gitpython!=3.1.19 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (3.1.43)
# Requirement already satisfied: semver in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (3.0.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (5.5.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (3.20.3)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (13.9.4)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (5.2)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (0.9.1)
# Requirement already satisfied: blinker>=1.0.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (1.9.0)
# Requirement already satisfied: pympler>=0.9 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (1.1)
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (18.1.0)
# Requirement already satisfied: torchvision in /usr/local/envs/invokeai/lib/python3.9/site-packages (from torch-fidelity==0.3.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 24)) (0.13.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from transformers==4.21.3->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 26)) (0.12.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from Werkzeug==2.2.2->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 35)) (3.0.2)
# Requirement already satisfied: greenlet>=1.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from eventlet->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 4)) (3.1.1)
# Requirement already satisfied: facexlib>=0.2.5 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from realesrgan->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 19)) (0.3.0)
# Requirement already satisfied: basicsr>=1.4.2 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from realesrgan->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 19)) (1.4.2)
# Requirement already satisfied: future in /usr/local/envs/invokeai/lib/python3.9/site-packages (from test-tube>=0.7.5->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 23)) (1.0.0)
# Requirement already satisfied: ftfy in /usr/local/envs/invokeai/lib/python3.9/site-packages (from clip->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 27)) (6.3.1)
# Requirement already satisfied: wandb in /usr/local/envs/invokeai/lib/python3.9/site-packages (from k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (0.19.0)
# Requirement already satisfied: resize-right in /usr/local/envs/invokeai/lib/python3.9/site-packages (from k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (0.0.2)
# Requirement already satisfied: jsonmerge in /usr/local/envs/invokeai/lib/python3.9/site-packages (from k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (1.9.2)
# Requirement already satisfied: accelerate in /usr/local/envs/invokeai/lib/python3.9/site-packages (from k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (0.32.1)
# Requirement already satisfied: torchsde in /usr/local/envs/invokeai/lib/python3.9/site-packages (from k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (0.2.6)
# Requirement already satisfied: clean-fid in /usr/local/envs/invokeai/lib/python3.9/site-packages (from k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (0.1.35)
# Requirement already satisfied: scikit-image in /usr/local/envs/invokeai/lib/python3.9/site-packages (from k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (0.20.0)
# Requirement already satisfied: torchdiffeq in /usr/local/envs/invokeai/lib/python3.9/site-packages (from k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (0.2.5)
# Requirement already satisfied: matplotlib in /usr/local/envs/invokeai/lib/python3.9/site-packages (from clipseg->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 29)) (3.9.3)
# Requirement already satisfied: lmdb in /usr/local/envs/invokeai/lib/python3.9/site-packages (from gfpgan->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 30)) (1.5.1)
# Requirement already satisfied: tb-nightly in /usr/local/envs/invokeai/lib/python3.9/site-packages (from gfpgan->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 30)) (2.19.0a20241208)
# Requirement already satisfied: yapf in /usr/local/envs/invokeai/lib/python3.9/site-packages (from gfpgan->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 30)) (0.43.0)
# Requirement already satisfied: addict in /usr/local/envs/invokeai/lib/python3.9/site-packages (from basicsr>=1.4.2->realesrgan->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 19)) (2.4.0)
# Requirement already satisfied: flaskwebgui in /usr/local/envs/invokeai/lib/python3.9/site-packages (from InvokeAI==2.2.5->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 32)) (1.1.6)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from altair>=3.2.0->streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (1.16.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from altair>=3.2.0->streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (4.23.0)
# Requirement already satisfied: numba in /usr/local/envs/invokeai/lib/python3.9/site-packages (from facexlib>=0.2.5->realesrgan->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 19)) (0.60.0)
# Requirement already satisfied: filterpy in /usr/local/envs/invokeai/lib/python3.9/site-packages (from facexlib>=0.2.5->realesrgan->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 19)) (1.4.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (3.11.10)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from gitpython!=3.1.19->streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (4.0.11)
# Requirement already satisfied: zipp>=3.20 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from importlib-metadata->diffusers==0.6.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 2)) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from pandas>=0.21.0->streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from pandas>=0.21.0->streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (2024.2)
# Requirement already satisfied: python-engineio>=4.8.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from python-socketio>=5.0.2->flask_socketio==5.3.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 7)) (4.10.1)
# Requirement already satisfied: bidict>=0.21.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from python-socketio>=5.0.2->flask_socketio==5.3.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 7)) (0.23.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from requests->diffusers==0.6.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from requests->diffusers==0.6.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 2)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from requests->diffusers==0.6.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 2)) (2024.8.30)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from requests->diffusers==0.6.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from rich>=10.11.0->streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (3.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from scikit-image->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (0.4)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from scikit-image->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (1.6.0)
# Requirement already satisfied: networkx>=2.8 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from scikit-image->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (3.2.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from scikit-image->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (2024.8.30)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (75.6.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (1.68.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (2.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (3.7)
# Requirement already satisfied: wcwidth in /usr/local/envs/invokeai/lib/python3.9/site-packages (from urwid>=1.1.1->pudb==2019.2->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 16)) (0.2.13)
# Requirement already satisfied: psutil in /usr/local/envs/invokeai/lib/python3.9/site-packages (from accelerate->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (6.1.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from accelerate->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (0.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from matplotlib->clipseg->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 29)) (3.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from matplotlib->clipseg->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 29)) (4.55.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from matplotlib->clipseg->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 29)) (6.4.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from matplotlib->clipseg->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 29)) (1.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from matplotlib->clipseg->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 29)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from matplotlib->clipseg->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 29)) (0.12.1)
# Requirement already satisfied: trampoline>=0.1.2 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from torchsde->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (0.1.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from wandb->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (0.4.0)
# Requirement already satisfied: platformdirs in /usr/local/envs/invokeai/lib/python3.9/site-packages (from wandb->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (4.3.6)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from wandb->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (2.19.2)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from wandb->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (2.10.3)
# Requirement already satisfied: setproctitle in /usr/local/envs/invokeai/lib/python3.9/site-packages (from wandb->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (1.3.4)
# Requirement already satisfied: eval-type-backport in /usr/local/envs/invokeai/lib/python3.9/site-packages (from wandb->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (0.2.0)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from yapf->gfpgan->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 30)) (2.2.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (2.4.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (6.1.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (1.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (1.18.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (24.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (5.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->streamlit==1.12.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 21)) (0.1.2)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from pydantic<3,>=2.6->wandb->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (2.27.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from pydantic<3,>=2.6->wandb->k-diffusion->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 28)) (0.7.0)
# Requirement already satisfied: simple-websocket>=0.10.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from python-engineio>=4.8.0->python-socketio>=5.0.2->flask_socketio==5.3.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from numba->facexlib>=0.2.5->realesrgan->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 19)) (0.43.0)
# Requirement already satisfied: wsproto in /usr/local/envs/invokeai/lib/python3.9/site-packages (from simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio>=5.0.2->flask_socketio==5.3.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/envs/invokeai/lib/python3.9/site-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio>=5.0.2->flask_socketio==5.3.0->-r /home/InvokeAI/condaenv.85wdb5tt.requirements.txt (line 7)) (0.14.0)
# Installing collected packages: InvokeAI
#   Attempting uninstall: InvokeAI
#     Found existing installation: InvokeAI 2.2.5
#     Uninstalling InvokeAI-2.2.5:
#       Successfully uninstalled InvokeAI-2.2.5
#   Running setup.py develop for InvokeAI
# Successfully installed InvokeAI-2.2.5
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate invokeai
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Loading Python libraries...
#
# Traceback (most recent call last):
#   File "/usr/local/envs/invokeai/lib/python3.9/site-packages/transformers/utils/import_utils.py", line 1002, in _get_module
#     return importlib.import_module("." + module_name, self.__name__)
#   File "/usr/local/envs/invokeai/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/usr/local/envs/invokeai/lib/python3.9/site-packages/transformers/models/clip/modeling_clip.py", line 27, in <module>
#     from ...modeling_utils import PreTrainedModel
#   File "/usr/local/envs/invokeai/lib/python3.9/site-packages/transformers/modeling_utils.py", line 79, in <module>
#     from accelerate import dispatch_model, infer_auto_device_map, init_empty_weights
#   File "/usr/local/envs/invokeai/lib/python3.9/site-packages/accelerate/__init__.py", line 16, in <module>
#     from .accelerator import Accelerator
#   File "/usr/local/envs/invokeai/lib/python3.9/site-packages/accelerate/accelerator.py", line 34, in <module>
#     from huggingface_hub import split_torch_state_dict_into_shards
# ImportError: cannot import name 'split_torch_state_dict_into_shards' from 'huggingface_hub' (/usr/local/envs/invokeai/lib/python3.9/site-packages/huggingface_hub/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/InvokeAI/scripts/configure_invokeai.py", line 24, in <module>
#     from transformers import CLIPTokenizer, CLIPTextModel
#   File "<frozen importlib._bootstrap>", line 1055, in _handle_fromlist
#   File "/usr/local/envs/invokeai/lib/python3.9/site-packages/transformers/utils/import_utils.py", line 993, in __getattr__
#     value = getattr(module, name)
#   File "/usr/local/envs/invokeai/lib/python3.9/site-packages/transformers/utils/import_utils.py", line 992, in __getattr__
#     module = self._get_module(self._class_to_module[name])
#   File "/usr/local/envs/invokeai/lib/python3.9/site-packages/transformers/utils/import_utils.py", line 1004, in _get_module
#     raise RuntimeError(
# RuntimeError: Failed to import transformers.models.clip.modeling_clip because of the following error (look up to see its traceback):
# cannot import name 'split_torch_state_dict_into_shards' from 'huggingface_hub' (/usr/local/envs/invokeai/lib/python3.9/site-packages/huggingface_hub/__init__.py)
# cp: cannot create regular file '/root/invokeai/configs': No such file or directory

# %%
#@title Установка модели Anything { display-mode: "form" }
import os

#@markdown Установка модели Anything V5.
#@markdown
#@markdown Anything V5 - 4 ГБ

os.system('cd /')
os.system('mkdir -p /root/invokeai/models/ldm/stable-diffusion-v1')

if not os.path.exists('/content/drive/MyDrive/models/Anything-V5.ckpt'):
    print('Производится скачивание модели Anything-V5')
    os.system('mkdir -p /content/drive/MyDrive/models/')
    os.system('wget -O /content/drive/MyDrive/models/Anything-V5.ckpt https://civitai.com/api/download/models/33672')


if os.path.exists('/content/drive/MyDrive/models/Anything-V5-vae.safetensors'):
  None
else:
  print('Производится скачивание Anything-VAE')
  os.system('wget -O /content/drive/MyDrive/models/Anything-V5-vae.safetensors https://huggingface.co/stablediffusionapi/anything-v5/resolve/main/vae/diffusion_pytorch_model.safetensors')

if os.path.exists('/content/drive/MyDrive/models/vae-ft-mse-840000-ema-pruned.ckpt'):
  None
else:
  print('Производится скачивание SD-VAE')
  os.system('wget -O /content/drive/MyDrive/models/vae-ft-mse-840000-ema-pruned.ckpt https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt')

if not os.path.exists('/content/drive/MyDrive/models/vae-ft-mse-840000-ema-pruned.ckpt') or not os.path.exists('/content/drive/MyDrive/models/Anything-V5-vae.safetensors') or not os.path.exists('/content/drive/MyDrive/models/Anything-V5.ckpt'):
    print('Произошла ошибка, попробуйте еще раз\nUnexpected error')
else:
    print('Make sure you accept the terms at https://huggingface.co/stablediffusionapi/anything-v5 and https://huggingface.co/stabilityai/sd-vae-ft-mse-original')


# %mkdir -p /root/invokeai/models/ldm/stable-diffusion-v1/
# !ln -s  /content/drive/MyDrive/models/Anything-V5.ckpt /root/invokeai/models/ldm/stable-diffusion-v1/Anything-V5.ckpt
# !ls -l /root/invokeai/models/ldm/stable-diffusion-v1/Anything-V5.ckpt


# !ln -s  /content/drive/MyDrive/models/vae-ft-mse-840000-ema-pruned.ckpt /root/invokeai/models/ldm/stable-diffusion-v1/vae-ft-mse-840000-ema-pruned.ckpt
# !ls -l /root/invokeai/models/ldm/stable-diffusion-v1/vae-ft-mse-840000-ema-pruned.ckpt

# !ln -s  /content/drive/MyDrive/models/Anything-V5-vae.safetensors /root/invokeai/models/ldm/stable-diffusion-v1/Anything-V5-vae.safetensors
# !ls -l /root/invokeai/models/ldm/stable-diffusion-v1/Anything-V5-vae.safetensors

# %%
#@title Запуск сервера { display-mode: "both" }
#@markdown Вставьте токен с [ngrok](https://dashboard.ngrok.com/get-started/your-authtoken) в поле перед выполнением кода.

ngrok_token = "2prx9CVTv6X0mpj3irY8VRt8gJE_7M3D9UHqafjngGYrz3CDs" #@param {type:"string"}
nsfw_checker = 0 #@param {type:"slider", min:0, max:1, step:1}
used_vae = "Anything-V5.vae" #@param ["Anything-V5.vae", "vae-ft-mse-840000-ema-pruned"]

import os
from pyngrok import ngrok

ngrok.kill()
ngrok.set_auth_token(ngrok_token)
public_url = ngrok.connect(9090).public_url
print(f'Invoke Ai public url: {public_url}')

# %cd /home/InvokeAI

model_name = "Anything_v5_vaefixed"
if used_vae == "vae-ft-mse-840000-ema-pruned":
    if model_name == "Anything_v5_vaefixed":
      model_name = "Anything_v5_default"


if nsfw_checker:
    # !source activate invokeai ; python scripts/invoke.py --web --model $model_name
else:
    # !source activate invokeai ; python scripts/invoke.py --web --no-nsfw_checker --model $model_name

# %% [markdown]
# # После запуска сервера нужно перейти по первой ссылке из вывода (Invoke Ai public url)
# Если интерфейс не прогрузился, надо перезагрузить страницу
# ---
